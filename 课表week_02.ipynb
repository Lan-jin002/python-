# %% [markdown]
# # 课表

# %%
print('_'*125)
print('|{:^17}|{:^17}|{:^17}|{:^17}|{:^17}|{:^17}|'.format('时间','星期一','星期二','星期三','星期四','星期五'))

print('_'*125)
print('|{:^16}|{:^20}|{:^20}|{:^20}|{:^13}|{:^16}|'.format('第一节','','','','大学英语（三）B1','Illustrator软件应用'))
print('|{:^19}|{:^20}|{:^20}|{:^20}|{:^18}|{:^13}|'.format('8:00-8:45','','','','洪明@9-204','阚风霞@新综合楼612'))

print('_'*82,'|','','','','','','','','','','','','','','','','','','','','|','','','','','','','','','','','','','','','','','','','','|')
print('|{:^16}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('第二节','','','','',''))
print('|{:^19}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('8:50-9:30','','','','',''))

print('_'*125)
print('|{:^16}|{:^20}|{:^20}|{:^20}|{:^18}|{:^20}|'.format('第三节','','','','Python语言',''))
print('|{:^19}|{:^20}|{:^20}|{:^20}|{:^13}|{:^20}|'.format('8:00-8:45','','','','许智超@新综合楼612',''))

print('_'*82,'|','','','','','','','','','','','','','','','','','','','','|','毛泽东思想和中国特','|')
print('|{:^16}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('第四节','','','','',''))
print('|{:^19}|{:^20}|{:^20}|{:^20}|{:^20}|{:^11}|'.format('10:00-11:25','','','','','色社会主义理论体系'))

print('_'*82,'|','','','','','','','','','','','','','','','','','','','','|','','','','','','','','','','','','','','','','','','','','|')
print('|{:^16}|{:^20}|{:^20}|{:^20}|{:^20}|{:^14}|'.format('第五节','','','','','概论（实践）'))
print('|{:^19}|{:^20}|{:^20}|{:^20}|{:^20}|{:^17}|'.format('11:35-12:00','','','','','杨益孜@7-402'))

print('_'*19,'|','','','','','','','','','','','','','','','','','','','','|','_'*82)
print('|{:^16}|{:^16}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('第六节','写作训练','','','',''))
print('|{:^19}|{:^17}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('12:50-13:35','周秀梅@1-104','','','',''))

print('_'*125)
print('|{:^16}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('第七节','','','','',''))
print('|{:^17}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('13：40-14：20','','','','',''))

print('_'*125)
print('|{:^16}|{:^16}|{:^13}|{:^20}|{:^14}|{:^20}|'.format('第八节','创业基础','H5互动技术与应用','','广告文案写作',''))
print('|{:^17}|{:^18}|{:^17}|{:^20}|{:^18}|{:^20}|'.format('14：30-15：10','高进@1-401','游鸽@3实308','','罗希@1-303',''))

print('_'*19,'|','','','','','','','','','','','','','','','','','','','','|','','','','','','','','','','','','','','','','','','','','|','_'*18,'|','','','','','','','','','','','','','','','','','','','','|','_'*18,'|')
print('|{:^16}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('第九节','','','','',''))
print('|{:^17}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('14：30-15：55','','','','',''))

print('_'*19,'|','','','','','','','','','','','','','','','','','','','','|','_'*82)
print('|{:^16}|{:^20}|{:^13}|{:^20}|{:^15}|{:^20}|'.format('第十节','','大学英语（三）B1','','武术 巩森森',''))
print('|{:^17}|{:^20}|{:^18}|{:^20}|{:^13}|{:^20}|'.format('16：10-16：50','','洪明@9-202','','@西区体育馆西面',''))

print('|{:^16}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('___________________','___________________','','___________________','','___________________'))
print('|{:^15}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('第十一节','','','','',''))
print('|{:^17}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('16：55-17：35','','','','',''))

print('_'*125)
print('|{:^15}|{:^20}|{:^20}|{:^20}|{:^12}|{:^20}|'.format('第十二节','','','','毛泽东思想和中国',''))
print('|{:^17}|{:^20}|{:^20}|{:^20}|{:^12}|{:^20}|'.format('18：45-19：25','','','','特色社会主义理论',''))

print('_'*82,'|','','','','','','','体系概论','','','','','|','___________________''|')
print('|{:^15}|{:^20}|{:^20}|{:^20}|{:^17}|{:^20}|'.format('第十三节','','','','张锦标@9-201',''))
print('|{:^17}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('19：30-20：10','','','','',''))

print('_'*82,'|','','','','','','','','','','','','','','','','','','','','|','___________________''|')
print('|{:^15}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('第十四节','','','','',''))
print('|{:^17}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('20：15-20：55','','','','',''))

print('_'*125)
print('|{:^15}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('第十五节','','','','',''))
print('|{:^17}|{:^20}|{:^20}|{:^20}|{:^20}|{:^20}|'.format('21：05-21：45','','','','',''))
print('_'*125)
# Out:
# _____________________________________________________________________________________________________________________________
# |       时间        |       星期一       |       星期二       |       星期三       |       星期四       |       星期五       |
# _____________________________________________________________________________________________________________________________
# |      第一节       |                    |                    |                    |  大学英语（三）B1  |Illustrator软件应用 |
# |     8:00-8:45     |                    |                    |                    |     洪明@9-204     | 阚风霞@新综合楼612 |
# __________________________________________________________________________________ |                    |                    |
# |      第二节       |                    |                    |                    |                    |                    |
# |     8:50-9:30     |                    |                    |                    |                    |                    |
# ...

# %% [markdown]
# # 课程查询

# %%
import datetime
time = datetime.datetime.today().weekday()
week_time = int(time)
if week_time==1:
    print("星期一");
    print("写作训练 周秀梅@1-104");
    print("创业基础 高进@1-401");
elif week_time==2:
    print("星期二");
    print("H5互动技术与应用 游鸽@3实308");
    print("大学英语（三）B1 洪明@9-202");
elif week_time==3:
    print("星期三");print("没课 歇着");
elif week_time==4:
    print("星期四");
    print("大学英语（三）B1 洪明@9-204");
    print("Python语言 许智超@新综合楼612")
    print("广告文案写作 罗希@1-303 ");
    print("武术 巩森森 @西区体育馆西面 ");
    print("毛泽东思想和中国特色社会主义理论体系概论  张锦标@9-201 ");
    print("今天满课！！！");
elif week_time==5:
    print("星期五");
    print("Illustrator软件应用 阚风霞@新综合楼612");
    print("毛泽东思想和中国特色社会主义理论体系概论（实践）杨益孜@7-402 ");
else:
    print("周六、周日");print("没课！！嗨皮！！！");
print('')
# Out:
# 星期一
# 写作训练 周秀梅@1-104
# 创业基础 高进@1-401

# %%
for i in range(3):
    q=input('想要上课吗 yes or no ')
    if q=='yes':
        print('可以，有前途')
        break
    else:
        print('你的思想很危险啊！')
# Out:
# 想要上课吗 yes or no yes
# 可以，有前途
